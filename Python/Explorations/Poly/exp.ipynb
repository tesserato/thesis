# %% [markdown]
# $$ \mathcal{I}(f,\phi) = \sum_{x=0}^{n-1}  W[x] \cos \left( \phi + 2 \pi f \frac{x}{n} \right) $$

# %%
import sympy as sp

n, x, k, s, x0, x1 = sp.symbols("n x k s_x x_0 x_1", integer=True, positive=True)
d, c, p, f, w = sp.symbols("d c \phi f \omega", real=True, positive=True)
W = sp.Function("W", real=True, size=1)(x)
v = sp.Function("v", real=True, size=1)(f, x) # k pi

def cos1(x):
    return sp.Sum((-1)**k * sp.exp(d*(x-k*sp.pi-s)**2), (k, -sp.oo, sp.oo))

def cos2(x):
    return c/(d*(x-s)**2+1)+sp.Sum(c*(-1)**k / (1 + d*(x - k * sp.pi - s)**2) + c*(-1)**k / (1 +d*(x + k * sp.pi-s)**2), (k, 1, sp.oo))

def cos3(x):
    s = (x // (2 * sp.pi)) * 2 * sp.pi
    return sp.Sum(c*(-1)**k / (1 + d*(x - k * sp.pi - s)**2), (k, -10, 10))

def a(x):
    return W * cos1(p + (2 * sp.pi * f / n) * x) # w = (2 * sp.pi * f / n)

I = sp.Sum(a(x), (x,0,n-1))
I#.subs(-sp.oo, -1).subs(sp.oo, 1).doit()
# Out:
# Sum(W(x)*Sum((-1)**k*exp(d*(\phi + 2*pi*f*x/n - pi*k - s_x)**2), (k, -oo, oo)), (x, 0, n - 1))

# %%
(-1)**k * sp.exp(d*(x-k*sp.pi-s)**2)+(-1)**k * sp.exp(d*(x+k*sp.pi-s)**2)
# Out:
# (-1)**k*exp(d*(-pi*k - s_x + x)**2) + (-1)**k*exp(d*(pi*k - s_x + x)**2)

# %%
dd = I.diff(f).subs(-sp.oo, -1).subs(sp.oo, 1).doit()
dd
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     261         try:
# --> 262             return self._assumptions[fact]
#     263         except KeyError:
#
# KeyError: 'negative'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     261         try:
# --> 262             return self._assumptions[fact]
#     263         except KeyError:
#
# KeyError: 'extended_negative'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-ffde48b29a01> in <module>
# ...

# %%
sp.solve(dd, f)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-ab07f2ef87e1> in <module>
# ----> 1 sp.solve(dd, f)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\sympy\solvers\solvers.py in solve(f, *symbols, **flags)
#    1172     ###########################################################################
#    1173     if bare_f:
# -> 1174         solution = _solve(f[0], *symbols, **flags)
#    1175     else:
#    1176         solution = _solve_system(f, symbols, **flags)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1454                 result = set()
#    1455                 break
# -> 1456             soln = _solve(m, symbol, **flags)
#    1457             result.update(set(soln))
#    1458         result = list(result)
#
# ...

# %%
cos1(x).subs(-sp.oo, -3).subs(sp.oo, 3).doit().factor()
# Out:
# -c**(d*x**2)*(c**(9*pi**2*d)*c**(6*pi*d*x) + c**(9*pi**2*d)*c**(-6*pi*d*x) - c**(4*pi**2*d)*c**(4*pi*d*x) - c**(4*pi**2*d)*c**(-4*pi*d*x) + c**(pi**2*d)*c**(2*pi*d*x) + c**(pi**2*d)*c**(-2*pi*d*x) - 1)

# %%
cos1(x).subs(-sp.oo, -2).subs(sp.oo, 2).doit().factor() == cos2(x).subs(sp.oo, 2).doit().factor()
# Out:
# True

# %%
cos1(x)
# Out:
# Sum((-1)**k*c/(d*(-pi*k - s_x + x)**2 + 1), (k, -oo, oo))

# %%
cos2(x).doit()
# Out:
# c/(d*(-s_x + x)**2 + 1) + Sum((-1)**k*c/(d*(pi*k - s_x + x)**2 + 1) + (-1)**k*c/(d*(-pi*k - s_x + x)**2 + 1), (k, 1, oo))

# %%
cos3(x).diff(x)

# %%
cos1(x).diff(x)

# %%
cos3(99999 * sp.pi / 2).subs(c, 1.7).subs(d, 0.3).evalf()

# %%
cos3(sp.pi/2).subs(c, 1.7).subs(d, 0.3).evalf()

# %%
S.expand().factor()

# %%
(1/(x+sp.pi)**2+1/(x-sp.pi)**2).expand().factor()

# %%
cos(0).doit()

# %%
(a(x).subs(p, 0) + a(x).subs(p, sp.pi/2)).factor().simplify()

# %%
denominator = n**2 + 4 * sp.pi**2 * x**2
Vp = (2 * sp.pi * n**2) / denominator
Vf = (4 * sp.pi**2 * n * x) / denominator
Vm = sp.sqrt(Vp**2 + Vf**2).simplify()

V = sp.Matrix([Vp, Vf]) # == sp.sqrt(V.T @ V)

U = V / Vm
P = sp.Matrix([p0, f0])
O = sp.Matrix([s * sp.pi, 2 * sp.pi * k]) # s=0 if w[t] > 0, 1 cc

d = sp.sqrt((P-O).T @ U@U.T @(P-O))[0, 0].simplify()

l = sp.Eq(n * k / x - n * p / (2 * sp.pi * x) + n * s / (2 * x), f)
l

# %%
print(sp.solve(l, p)[0].subs(f, 0))

# %%
dkp = (2 * sp.pi * k + sp.pi * s) * n**2 / (n**2 + 4 * sp.pi**2 * x**2)
dkf = (2 * sp.pi * k + sp.pi * s) * 2 * sp.pi * n * x / (n**2 + 4 * sp.pi**2 * x**2)
dk = sp.sqrt(dkp**2 + dkf**2)
dk.expand().factor().simplify()

# %%
r = ((d - k * Vm)).expand().simplify() # residual distance to closest line
r

# %% [markdown]
# -----

# %%
import plotly.graph_objects as go
import numpy as np

n = 100
X = np.arange(n)
f = 10
p = 0
W = np.cos(p + 2 * np.pi * f * X / n)

Q = np.zeros((n, 2))
Y = np.zeros((n))

for t in range(n):
    s = 0 if W[t] >= 0 else 1
    Q[t, 0] = n * W[t]
    Q[t, 1] = 2 * np.pi * t * W[t]
    Y[t] = np.pi * n * s * W[t]

A = np.linalg.inv(Q.T @ Q) @ Q.T @ Y

A

# %%
Q
