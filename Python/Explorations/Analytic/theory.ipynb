# %% [markdown]
# $$ \mathcal{I}(f,\phi) = \sum_{x=0}^{n-1}  W[x] \cos \left( \phi + 2 \pi f \frac{x}{n} \right) $$

# %%
import sympy as sp

n, x, k, s = sp.symbols("n x k s", integer=True, positive=True)
p0, f0, p, f, w = sp.symbols("\phi_0 f_0 \phi f \omega", real=True, positive=True)
W = sp.Function("W", real=True)

def a(x):
    return W(x) * sp.cos(p + w * x) # w = 2 * sp.pi * f / n

I = sp.Sum(a(x), (x,0,n-1))

I
# Out:
# Sum(W(x)*cos(\omega*x + \phi), (x, 0, n - 1))

# %%
u  = sp.cos(p + w * x)
dv = W(x)

v  = dv.integrate((x))
du = u.diff(x)

u * dv
# Out:
# W(x)*cos(\omega*x + \phi)

# %%
(u * v - (v * du).integrate((x)))
# Out:
# \omega*Integral(sin(\omega*x + \phi)*Integral(W(x), x), x) + cos(\omega*x + \phi)*Integral(W(x), x)

# %%
w/n * (sp.sin(p + w * x / n) * s).integrate(x)
# Out:
# -s*cos(\omega*x/n + \phi)

# %%
u  = sp.sin(p + w * x / n)
dv = W.integrate((x))

v  = dv.integrate((x)) 
du = u.diff(x)

u.integrate((x))
# Out:
# -n*cos(\omega*x/n + \phi)/\omega

# %%
(u * v - (v * du).integrate((x, 0, n-1)))
# Out:
# -\omega**2*Integral(cos(\omega*x/n + \phi)*Integral(W(x), x, x), (x, 0, n - 1))/n**2 + \omega*sin(\omega*x/n + \phi)*Integral(W(x), x, x)/n

# %%
eq = sp.diff(I, p).expand(trig=True)0
eq
# Out:
# Sum(-W(x)*sin(\phi)*cos(\omega*x/n), (x, 0, n - 1)) + Sum(-W(x)*sin(\omega*x/n)*cos(\phi), (x, 0, n - 1))

# %%
p_max = -sp.atan(
    sp.Sum(W[x] * sp.sin(w * x / n), (x, 0, n-1))   / 
    sp.Sum(W[x] * sp.cos(w * x / n), (x, 0, n-1))
)#.subs(n, 4).doit()
p_max
# Out:
# -atan(Sum(sin(\omega*x/n)*W[x], (x, 0, n - 1))/Sum(cos(\omega*x/n)*W[x], (x, 0, n - 1)))

# %%
I.subs(p, p_max)
# Out:
# Sum(cos(\omega*x/n - atan(Sum(sin(\omega*x/n)*W[x], (x, 0, n - 1))/Sum(cos(\omega*x/n)*W[x], (x, 0, n - 1))))*W[x], (x, 0, n - 1))

# %%
Vp = (2 * sp.pi * n**2) / (n**2 + 4 * sp.pi**2 * x**2)      # p
Vf = (4 * sp.pi**2 * n * x) / (n**2 + 4 * sp.pi**2 * x**2)  # f
Vm = sp.sqrt(Vp**2 + Vf**2).simplify()

V = sp.Matrix([Vp, Vf]) # == sp.sqrt(V.T @ V)

U = V / Vm
P=sp.Matrix([p0, f0])
O=sp.Matrix([s * sp.pi, 0]) # s=0 if w[t] > 0, 1 cc

d=sp.sqrt((P-O).T @ U@U.T @(P-O))[0, 0].simplify()

l = sp.Eq(n * k / x - n * p / (2 * sp.pi * x) + n * s / (2 * x), f)
# Out:
# Eq(k*n/t - n*p/(2*pi*t) + n*s/(2*t), f)

# %%
print(U)
# Out:
# Matrix([[n/sqrt(n**2 + 4*pi**2*t**2)], [2*pi*t/sqrt(n**2 + 4*pi**2*t**2)]])

# %%
d = (n*(sp.pi*s - x0) + 2*sp.pi*t*y0)/sp.sqrt(n**2 + 4*sp.pi**2*t**2)
d
# Out:
# (n*(pi*s_t - x_0) + 2*pi*t*y_0)/sqrt(n**2 + 4*pi**2*t**2)

# %%
m_vec.simplify()
# Out:
# 2*pi*n/sqrt(n**2 + 4*pi**2*t**2)

# %%
r = (  m_vec / 2 - sp.sqrt((d - k * m_vec + m_vec/2)**2) ).simplify()
r
# Out:
# (pi*n*(n**2 + 4*pi**2*t**2) - Abs(-2*pi*k_t*n*sqrt(n**4 + 8*pi**2*n**2*t**2 + 16*pi**4*t**4) + pi*n*(n**2 + 4*pi**2*t**2) + (n**2 + 4*pi**2*t**2)*Abs(n*(pi*s_t - x_0) - 2*pi*t*y_0)))/(n**2 + 4*pi**2*t**2)**(3/2)

# %%
sp.diff(r, k)
# Out:
# -2*pi*n*sqrt((2*pi*k_t*n + n*(pi*s_t - x_0) - pi*n - 2*pi*t*y_0)**2)/(sqrt(n**2 + 4*pi**2*t**2)*(2*pi*k_t*n + n*(pi*s_t - x_0) - pi*n - 2*pi*t*y_0))

# %%
wr = r * W[t]
wr
# Out:
# (pi*n - sqrt((-2*pi*k_t*n + pi*n + sqrt((n*(pi*s_t - x_0) - 2*pi*t*y_0)**2))**2))*W[t]/sqrt(n**2 + 4*pi**2*t**2)

# %%
dwrdx0 = sp.diff(wr, x0)#.simplify()
dwrdx0
# Out:
# n*sqrt((n*(pi*s_t - x_0) - 2*pi*t*y_0)**2)*sqrt((-2*pi*k_t*n + pi*n + sqrt((n*(pi*s_t - x_0) - 2*pi*t*y_0)**2))**2)*W[t]/(sqrt(n**2 + 4*pi**2*t**2)*(n*(pi*s_t - x_0) - 2*pi*t*y_0)*(-2*pi*k_t*n + pi*n + sqrt((n*(pi*s_t - x_0) - 2*pi*t*y_0)**2)))

# %%
dwrdy0 = sp.diff(wr, y0).simplify()
dwrdy0
# Out:
# 2*pi*t*sqrt((n*(pi*s_t - x_0) - 2*pi*t*y_0)**2)*sqrt((-2*pi*k_t*n + pi*n + sqrt((n*(pi*s_t - x_0) - 2*pi*t*y_0)**2))**2)*W[t]/(sqrt(n**2 + 4*pi**2*t**2)*(n*(pi*s_t - x_0) - 2*pi*t*y_0)*(-2*pi*k_t*n + pi*n + sqrt((n*(pi*s_t - x_0) - 2*pi*t*y_0)**2)))

# %%
equation = ( n * (sp.pi * s - x0) - 2 * sp.pi * t * y0) * W[t]
sp.Eq(equation, 0).expand()
# Out:
# Eq(pi*n*s_t*W[t] - n*x_0*W[t] - 2*pi*t*y_0*W[t], 0)

# %%
equation2=sp.pi * n * s * W[t] - n * x0 * W[t] - 2 * sp.pi * t * y0 * W[t]
equation2.expand()
# Out:
# pi*n*s_t*W[t] - n*x_0*W[t] - 2*pi*t*y_0*W[t]

# %%
equation2.expand()==equation.expand()
# Out:
# True

# %%
import plotly.graph_objects as go
import numpy as np

n = 100
X = np.arange(n)
f = 10
p = 0
W = np.cos(p + 2 * np.pi * f * X / n)

Q = np.zeros((n, 2))
Y = np.zeros((n))

for t in range(n):
    s = 0 if W[t] >= 0 else 1
    Q[t, 0] = n * W[t]
    Q[t, 1] = 2 * np.pi * t * W[t]
    Y[t] = np.pi * n * s * W[t]

A = np.linalg.inv(Q.T @ Q) @ Q.T @ Y

A
# Out:
# array([1.47850149, 0.02997792])

# %%
Q
# Out:
# array([[ 100.        ,    0.        ],
#        [  80.90169944,    5.08320369],
#        [  30.90169944,    3.88322208],
#        [ -30.90169944,   -5.82483312],
#        [ -80.90169944,  -20.33281477],
#        [-100.        ,  -31.41592654],
#        [ -80.90169944,  -30.49922215],
#        [ -30.90169944,  -13.59127727],
#        [  30.90169944,   15.53288831],
#        [  80.90169944,   45.74883323],
#        [ 100.        ,   62.83185307],
#        [  80.90169944,   55.91524062],
#        [  30.90169944,   23.29933246],
#        [ -30.90169944,  -25.2409435 ],
#        [ -80.90169944,  -71.16485169],
#        [-100.        ,  -94.24777961],
#        [ -80.90169944,  -81.33125908],
#        [ -30.90169944,  -33.00738766],
#        [  30.90169944,   34.9489987 ],
#        [  80.90169944,   96.58087015],
#        [ 100.        ,  125.66370614],
#        [  80.90169944,  106.74727754],
#        [  30.90169944,   42.71544285],
#        [ -30.90169944,  -44.65705389],
# ...
