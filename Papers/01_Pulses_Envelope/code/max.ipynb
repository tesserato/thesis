# %%
import sympy as sp
w, w_, e, c, de, dc, s = sp.symbols("w w_ e_i c_i \Delta{e} \Delta{c} s", real=True, positive=True)

# %%
#w = e * c
#w

# %%
w_ = (e + de) * (c - dc)
sp.latex(w_.expand().subs(de, 0))
# Out:
# '- \\Delta{c} e_{i} + c_{i} e_{i}'

# %%
w_.subs(dc, de+s).expand().subs(de, 0)
# Out:
# c_i*e_i - e_i*s

# %%
w_.subs(dc, de+s).expand().subs(c, 1).subs(e, w)#.factor()
# Out:
# -\Delta{e}**2 - \Delta{e}*s - \Delta{e}*w + \Delta{e} - s*w + w
