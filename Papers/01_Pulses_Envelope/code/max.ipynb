# %%
import sympy as sp
w, w_, e, c, de, dc, s = sp.symbols("w w_ e c de dc s", real=True, positive=True)

# %%
#w = e * c
#w

# %%
w_ = (e + de) * (c - dc)
w_
# Out:
# (c - dc)*(de + e)

# %%
w_.subs(dc, de+s).expand()
# Out:
# c*de + c*e - de**2 - de*e - de*s - e*s

# %%
w_.subs(dc, de+s).expand().subs(c, 1).subs(e, w)#.factor()
# Out:
# -(de + w)*(de + s - 1)
