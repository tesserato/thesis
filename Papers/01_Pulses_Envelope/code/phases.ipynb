# %%
import sympy as sp
f, p, i, n, k = sp.symbols("f \phi i n k", real=True, positive=True)
eq = sp.Eq(sp.cos(p + 2 * sp.pi * f * i / n), 1)
eq
# Out:
# Eq(cos(\phi + 2*pi*f*i/n), 1)

# %%
sp.acos(-1).doit()
# Out:
# pi

# %%
sp.cos(sp.pi + k * 2 * sp.pi)
# Out:
# -1

# %%
eq2 = sp.Eq(p + 2 * sp.pi * f * i / n, sp.pi + k * 2 * sp.pi)
eq2
# Out:
# Eq(\phi + 2*pi*f*i/n, 2*pi*k + pi)

# %%
sp.solve(eq2, p)[0].simplify()
# Out:
# -2*pi*f*i/n + 2*pi*k + pi
