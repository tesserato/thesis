# %%
import sympy as sp

dx, dy, x, y, x0, x1, x2, y0, y1, y2, a, b, c, r, xc, yc, dl = sp.symbols("dx dy x y x_0 x_1 x_2 y_0 y_1 y_2 a b c r x_c y_c d_l", real=True, positive=True)

# dy = a dx + b

y = (a * dx + b + dy - y) / (x + dx - x) * x + b
y
# Out:
# b + x*(a*dx + b + dy - y)/dx

# %%
y.diff(x).diff(x)
# Out:
# 0

# %%
y.diff(x).diff(x) / (1 + y.diff(x))**sp.Rational(2, 3)
# Out:
# 0

# %%
((1 + y.diff(x))**sp.Rational(2, 3) / y.diff(x).diff(x)).simplify()#.subs(y0, y)#.subs(x0, x)
# Out:
# zoo*(a*dx + b + dx + dy - y)**(2/3)
